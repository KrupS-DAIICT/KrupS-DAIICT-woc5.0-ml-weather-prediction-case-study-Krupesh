# %% [markdown]
# Exercise 1)

# %%
# Exercise 1: Relu function
def relu(x):
  if x>=0:
    ans=x
  else:
    ans=0
  return ans

relu(-3)
# Out:
# 0

# %% [markdown]
# Exercise 2)

# %%
a = [1,2,3,4,5,6]
a[3:]
# Out:
# [4, 5, 6]
